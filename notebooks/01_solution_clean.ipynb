# %% [markdown]
# # NLP Test Task — Internship at SberDevices (IDP)
#
# Решение тестового задания по извлечению именованных сущностей из русскоязычных новостных документов с использованием LLM и классических методов анализа.

# %% [markdown]
# ---
#
# ## 🔹 Задание 1: Теоретическое описание задачи
#
# **Формулировка:**
# Опишите задачу с точки зрения NLP. Что это за задача, какие классические методы существуют для её решения? Как её можно решать через LLM? Как обычно оценивают качество моделей в этой задаче?
#
# ### ✅ Решение:

# %% [markdown]
# ---
#
# ## 🔹 Задание 2: Загрузка и подготовка датасета
#
# **Формулировка:**
# Реализуйте чтение датасета в pandas DataFrame с обязательными колонками:
# - `document_id`
# - `document_text`
# - `entity`
# - `gold_answer`
#
# Выведите шапку датафрейма.

# %%
# Загрузка и отображение DataFrame

# %% [markdown]
# ---
#
# ## 🔹 Задание 3: Формирование prompt-функции для LLM
#
# **Формулировка:**
# <сюда можно вставить формулировку из ТЗ>
#
# ### ✅ Решение:

# %%
# Код для задания 3

# %% [markdown]
# ---
#
# ## 🔹 Задание 4: Ручное получение ответов от GigaChat и сохранение
#
# **Формулировка:**
# <сюда можно вставить формулировку из ТЗ>
#
# ### ✅ Решение:

# %%
# Код для задания 4

# %% [markdown]
# ---
#
# ## 🔹 Задание 5: Реализация метрики score_fn() и юнит-тесты
#
# **Формулировка:**
# <сюда можно вставить формулировку из ТЗ>
#
# ### ✅ Решение:

# %%
# Код для задания 5

# %% [markdown]
# ---
#
# ## 🔹 Задание 6: Расчёт метрик и визуализация по сущностям/документам
#
# **Формулировка:**
# <сюда можно вставить формулировку из ТЗ>
#
# ### ✅ Решение:

# %%
# Код для задания 6

# %% [markdown]
# ---
#
# ## 🔹 Задание 7: Анализ зависимости качества от длины документа
#
# **Формулировка:**
# <сюда можно вставить формулировку из ТЗ>
#
# ### ✅ Решение:

# %%
# Код для задания 7

# %% [markdown]
# ---
#
# ## 🔹 Задание 8: Анализ ошибок, слабых и сильных сторон модели
#
# **Формулировка:**
# <сюда можно вставить формулировку из ТЗ>
#
# ### ✅ Решение:

# %%
# Код для задания 8

# %% [markdown]
# ---
#
# ## 🔹 Задание 9: Выводы по проекту и самооценка
#
# **Формулировка:**
# <сюда можно вставить формулировку из ТЗ>
#
# ### ✅ Решение:

# %%
# Код для задания 9
